# %%
import numpy as np
import pandas as pd
from datetime import date
import datetime as dt

# %%
dfp=pd.read_csv('Copy of project_data.csv')

# %%
dfp.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# 2           0      3         11
# 3           0      3         11
# 4           0      3         11

# %%
dfe=pd.read_csv('Copy of edu_data.csv')

# %%
dfe.head()
# Out:
#   educational_level educational_status_code
# 0        Graduation                      GD
# 1               PhD                      PH
# 2            Master                      MS
# 3             Basic                      BS
# 4       High School                      HS

# %%
dfc_1=pd.read_excel('Copy of customer_data.xlsx',sheet_name='Data 1')

# %%
dfc_2=pd.read_excel('Copy of customer_data.xlsx',sheet_name='Data 2')

# %%
dfc=pd.concat([dfc_1,dfc_2],ignore_index=True)

# %%
dfc
# Out:
#       cust_id  year_of_birth educational_status_code marital_status  \
# 0    20201733           1940                      GD        Married
# 1    20202059           1943                     NaN        Married
# 2    20202195           1944                      PH       Divorced
# 3    20201983           1946                      GD   Relationship
# 4    20202060           1948                      PH       Divorced
# ..        ...            ...                     ...            ...
# 386  20201886           2000                      GD         Single
# 387  20202023           2000                      PH   Relationship
# 388  20202089           2000                      GD   Relationship
# 389  20202119           2000                      GD         Single
# 390  20202153           2000                      MS         Single
#
#      annual_income              full_name
# 0        40548.000            Abhinav Bal
# 1        65073.000            Nimai Neela
# ...

# %%
dfc.shape
# Out:
# (391, 6)

# %%
dfe.shape
# Out:
# (5, 2)

# %%
dfp.shape
# Out:
# (499, 8)

# %%
dfc.isnull().sum()
# Out:
# cust_id                     0
# year_of_birth               0
# educational_status_code    28
# marital_status              0
# annual_income              18
# full_name                   0
# dtype: int64

# %%
dfe.isnull().sum()
# Out:
# educational_level          0
# educational_status_code    0
# dtype: int64

# %%
dfp.isnull().sum()
# Out:
# customer_id         0
# purhcase_date       0
# recency             0
# online_purchases    0
# store_purchases     0
# complaints          0
# calls               0
# intercoms           0
# dtype: int64

# %%
dfc.head()
# Out:
#     cust_id  year_of_birth educational_status_code marital_status  \
# 0  20201733           1940                      GD        Married
# 1  20202059           1943                     NaN        Married
# 2  20202195           1944                      PH       Divorced
# 3  20201983           1946                      GD   Relationship
# 4  20202060           1948                      PH       Divorced
#
#    annual_income              full_name
# 0      40548.000            Abhinav Bal
# 1      65073.000            Nimai Neela
# 2      55614.000         Somatra Savant
# 3      46276.000            Kamana Nath
# 4      46681.000  Ninarika Chandrasekar

# %%
dfe.describe()
# Out:
#        educational_level educational_status_code
# count                  5                       5
# unique                 5                       5
# top           Graduation                      GD
# freq                   1                       1

# %%
dfp.describe()
# Out:
#        customer_id  recency  online_purchases  store_purchases  complaints  \
# count      499.000  499.000           499.000          499.000     499.000
# mean  20201950.000   48.228             3.970            5.780       0.253
# std        144.193   29.077             2.814            3.301       1.116
# min   20201701.000    0.000             0.000            0.000       0.000
# 25%   20201825.500   23.000             2.000            3.000       0.000
# 50%   20201950.000   47.000             3.000            5.000       0.000
# 75%   20202074.500   74.000             6.000            8.000       0.000
# max   20202199.000   99.000            27.000           13.000      11.000
#
#         calls  intercoms
# count 499.000    499.000
# mean    3.371     10.168
# std     4.327      2.801
# min     0.000      2.000
# 25%     3.000     11.000
# 50%     3.000     11.000
# 75%     3.000     11.000
# max    88.000     44.000

# %%
dfc.describe()
# Out:
#            cust_id  year_of_birth  annual_income
# count      391.000        391.000        373.000
# mean  20201950.263       1978.621      51113.949
# std        146.174         13.845      21152.036
# min   20201701.000       1940.000       2447.000
# 25%   20201822.000       1970.000      34554.000
# 50%   20201951.000       1982.000      50520.000
# 75%   20202082.500       1989.000      68491.000
# max   20202199.000       2000.000     102692.000

# %%
dfc[dfc["annual_income"].isnull()]
# Out:
#       cust_id  year_of_birth educational_status_code marital_status  \
# 10   20201749           1951                      GD        Married
# 33   20201791           1957                      PH   Relationship
# 34   20201792           1957                      GD        Married
# 49   20202157           1957                      HS         Single
# 56   20201744           1959                      PH       Divorced
# 59   20201829           1961                      PH        Married
# 130  20201793           1973                      MS   Relationship
# 143  20201985           1975                      MS        Married
# 171  20201834           1980                      GD   Relationship
# 197  20201759           1982                      GD   Relationship
# 211  20202005           1982                      GD   Relationship
# 217  20201711           1983                      GD         Single
# 259  20202105           1986                      PH       Divorced
# ...

# %%
pd.set_option('display.float_format',lambda x:'%.3F' %x)

# %%
dfp.describe()
# Out:
#        customer_id  recency  online_purchases  store_purchases  complaints  \
# count      499.000  499.000           499.000          499.000     499.000
# mean  20201950.000   48.228             3.970            5.780       0.253
# std        144.193   29.077             2.814            3.301       1.116
# min   20201701.000    0.000             0.000            0.000       0.000
# 25%   20201825.500   23.000             2.000            3.000       0.000
# 50%   20201950.000   47.000             3.000            5.000       0.000
# 75%   20202074.500   74.000             6.000            8.000       0.000
# max   20202199.000   99.000            27.000           13.000      11.000
#
#         calls  intercoms
# count 499.000    499.000
# mean    3.371     10.168
# std     4.327      2.801
# min     0.000      2.000
# 25%     3.000     11.000
# 50%     3.000     11.000
# 75%     3.000     11.000
# max    88.000     44.000

# %%
annual_income_avg=dfc.groupby('educational_status_code')['annual_income'].mean().reset_index()

# %%
annual_income_avg
# Out:
#   educational_status_code  annual_income
# 0                      BS      18058.833
# 1                      GD      51502.337
# 2                      HS      42864.880
# 3                      MS      52231.173
# 4                      PH      55420.920

# %%
dfc['annual_income']=dfc['annual_income'].fillna(dfc.groupby('educational_status_code')['annual_income'].transform('mean'))

# %%
dfc.head()
# Out:
#     cust_id  year_of_birth educational_status_code marital_status  \
# 0  20201733           1940                      GD        Married
# 1  20202059           1943                     NaN        Married
# 2  20202195           1944                      PH       Divorced
# 3  20201983           1946                      GD   Relationship
# 4  20202060           1948                      PH       Divorced
#
#    annual_income              full_name
# 0      40548.000            Abhinav Bal
# 1      65073.000            Nimai Neela
# 2      55614.000         Somatra Savant
# 3      46276.000            Kamana Nath
# 4      46681.000  Ninarika Chandrasekar

# %%
dfc.isnull().sum()
# Out:
# cust_id                     0
# year_of_birth               0
# educational_status_code    28
# marital_status              0
# annual_income               0
# full_name                   0
# dtype: int64

# %%
dfp.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# 2           0      3         11
# 3           0      3         11
# 4           0      3         11

# %%
dfc.head()
# Out:
#     cust_id  year_of_birth educational_status_code marital_status  \
# 0  20201733           1940                      GD        Married
# 1  20202059           1943                     NaN        Married
# 2  20202195           1944                      PH       Divorced
# 3  20201983           1946                      GD   Relationship
# 4  20202060           1948                      PH       Divorced
#
#    annual_income              full_name
# 0      40548.000            Abhinav Bal
# 1      65073.000            Nimai Neela
# 2      55614.000         Somatra Savant
# 3      46276.000            Kamana Nath
# 4      46681.000  Ninarika Chandrasekar

# %%
df_temp=pd.merge(dfp,dfc,left_on='customer_id',right_on='cust_id',how='left')

# %%
df_temp.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms      cust_id  year_of_birth  \
# 0           0      3         11 20201701.000       1982.000
# 1           0      3         11 20201702.000       1950.000
# 2           0      3         11 20201703.000       1965.000
# 3           0      3         11          NaN            NaN
# 4           0      3         11 20201705.000       1981.000
#
#   educational_status_code marital_status  annual_income         full_name
# 0                      GD         Single      58138.000     Aditi Acharya
# ...

# %%
dfe.head()
# Out:
#   educational_level educational_status_code
# 0        Graduation                      GD
# 1               PhD                      PH
# 2            Master                      MS
# 3             Basic                      BS
# 4       High School                      HS

# %%
df=pd.merge(df_temp,dfe,left_on='educational_status_code',right_on='educational_status_code',how='left')

# %%
df.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms      cust_id  year_of_birth  \
# 0           0      3         11 20201701.000       1982.000
# 1           0      3         11 20201702.000       1950.000
# 2           0      3         11 20201703.000       1965.000
# 3           0      3         11          NaN            NaN
# 4           0      3         11 20201705.000       1981.000
#
#   educational_status_code marital_status  annual_income         full_name  \
# 0                      GD         Single      58138.000     Aditi Acharya
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                    109
# year_of_birth              109
# educational_status_code    137
# marital_status             109
# annual_income              109
# full_name                  109
# educational_level          137
# dtype: int64

# %%
edu_details=df[['full_name','educational_level','annual_income','year_of_birth']]

# %%
edu_details.head()
# Out:
#           full_name educational_level  annual_income  year_of_birth
# 0     Aditi Acharya        Graduation      58138.000       1982.000
# 1  Advitiya Agarwal        Graduation      46344.000       1950.000
# 2    Alagesan Agate        Graduation      71613.000       1965.000
# 3               NaN               NaN            NaN            NaN
# 4   Amrish Aggarwal               PhD      58293.000       1981.000

# %%
df[df['annual_income'].isnull()]
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 3       20201704    02-10-2014       26                 2                4
# 7       20201708    05-08-2013       32                 4                4
# 9       20201710     3/13/2014       68                 1                0
# 27      20201728     2/20/2013       19                27                0
# 31      20201732    05-11-2013       56                 2                3
# ..           ...           ...      ...               ...              ...
# 483     20202183     8/19/2012       26                 6                2
# 484     20202184    10/30/2013       30                 4                5
# 485     20202185    10-10-2012       93                 5                4
# 488     20202188     6/26/2013       92                 7               10
# 490     20202190    10/28/2012       96                 4                4
#
#      complaints  calls  intercoms  cust_id  year_of_birth  \
# ...

# %%
df[df['educational_level']=='Master'].head()
# Out:
#     customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 5      20201706    09-09-2013       16                 6               10
# 13     20201714    11/15/2013       53                 6                5
# 18     20201719     3/28/2013       91                11                9
# 30     20201731     5/22/2014       34                 3                3
# 34     20201735     2/20/2013        4                 3                9
#
#     complaints  calls  intercoms      cust_id  year_of_birth  \
# 5            5      3         11 20201706.000       1967.000
# 13           0      3         11 20201714.000       1952.000
# 18           4      3         11 20201719.000       1980.000
# 30           8      3         11 20201731.000       1989.000
# 34           5      3         11 20201735.000       1975.000
#
#    educational_status_code marital_status  annual_income            full_name  \
# ...

# %%
df['year_of_birth']=df['year_of_birth'].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              500 non-null    int64
#  1   purhcase_date            500 non-null    object
#  2   recency                  500 non-null    int64
#  3   online_purchases         500 non-null    int64
#  4   store_purchases          500 non-null    int64
#  5   complaints               500 non-null    int64
#  6   calls                    500 non-null    int64
#  7   intercoms                500 non-null    int64
#  8   cust_id                  391 non-null    float64
#  9   year_of_birth            391 non-null    Int64
#  10  educational_status_code  363 non-null    object
#  11  marital_status           391 non-null    object
#  12  annual_income            391 non-null    float64
#  13  full_name                391 non-null    object
# ...

# %%
df.loc[:,['full_name','educational_level','annual_income','recency']].sort_values(by='recency',ascending=False).head(10)
# Out:
#             full_name educational_level  annual_income  recency
# 192        Hansa Vasa       High School      36640.000       99
# 492      Sneha Sarraf        Graduation      46310.000       99
# 445               NaN               NaN            NaN       99
# 208       Hiral Kunda        Graduation      44794.000       99
# 38        Adarsh Bala        Graduation      42429.000       99
# 191  Hajari Varughese               PhD      66973.000       98
# 240               NaN               NaN            NaN       98
# 164               NaN               NaN            NaN       98
# 257               NaN               NaN            NaN       97
# 241     Javed Mallick        Graduation      64961.000       97

# %%
df.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms      cust_id  year_of_birth  \
# 0           0      3         11 20201701.000           1982
# 1           0      3         11 20201702.000           1950
# 2           0      3         11 20201703.000           1965
# 3           0      3         11          NaN           <NA>
# 4           0      3         11 20201705.000           1981
#
#   educational_status_code marital_status  annual_income         full_name  \
# 0                      GD         Single      58138.000     Aditi Acharya
# ...

# %%
today=date.today()

# %%
today
# Out:
# datetime.date(2023, 5, 11)

# %%
year=int(today.year)

# %%
year
# Out:
# 2023

# %%
df['age']=year-df['year_of_birth']

# %%
df.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms      cust_id  year_of_birth  \
# 0           0      3         11 20201701.000           1982
# 1           0      3         11 20201702.000           1950
# 2           0      3         11 20201703.000           1965
# 3           0      3         11          NaN           <NA>
# 4           0      3         11 20201705.000           1981
#
#   educational_status_code marital_status  annual_income         full_name  \
# 0                      GD         Single      58138.000     Aditi Acharya
# ...

# %%
df.loc[df['marital_status'].isin(['Widowed','Divorced'])][['age','annual_income']].mean()
# Out:
# age                44.190
# annual_income   51658.424
# dtype: float64

# %%
df.iloc[list((df.annual_income>75000)& (df.educational_level=='Master')),:]
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 18      20201719     3/28/2013       91                11                9
# 51      20201752    08-11-2012        2                 6               13
# 60      20201761    07-04-2013       12                 3               11
# 76      20201777     8/27/2012       34                 7                5
# 120     20201821     6/20/2013       65                 6               10
# 140     20201841    10/19/2012       46                 5               12
# 217     20201918    11/15/2013       81                 8                6
# 424     20202124    06-04-2013       26                 3                8
# 436     20202136     6/21/2013       49                 1                3
#
#      complaints  calls  intercoms      cust_id  year_of_birth  \
# 18            4      3         11 20201719.000           1980
# 51            0      3         11 20201752.000           1964
# ...

# %%
df['all_purchase']=df.online_purchases+df.store_purchases

# %%
df.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms      cust_id  year_of_birth  \
# 0           0      3         11 20201701.000           1982
# 1           0      3         11 20201702.000           1950
# 2           0      3         11 20201703.000           1965
# 3           0      3         11          NaN           <NA>
# 4           0      3         11 20201705.000           1981
#
#   educational_status_code marital_status  annual_income         full_name  \
# 0                      GD         Single      58138.000     Aditi Acharya
# ...

# %%
df['annual_income'].max()
# Out:
# 102692.0

# %%
df['annual_income'].min()
# Out:
# 2447.0

# %%
def income_category(annual_income):
    if annual_income > 100000:
        return "High"
    elif (50000<annual_income<100000):
        return "Medium"
    else:
        return "low"

# %%
income_category(13890)
# Out:
# 'low'

# %%
df['income_category']=df.apply(lambda x:income_category(x['annual_income']),axis=1)

# %%
df.head()
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms      cust_id  year_of_birth  \
# 0           0      3         11 20201701.000           1982
# 1           0      3         11 20201702.000           1950
# 2           0      3         11 20201703.000           1965
# 3           0      3         11          NaN           <NA>
# 4           0      3         11 20201705.000           1981
#
#   educational_status_code marital_status  annual_income         full_name  \
# 0                      GD         Single      58138.000     Aditi Acharya
# ...

# %%
df[['annual_income','income_category']]
# Out:
#      annual_income income_category
# 0        58138.000          Medium
# 1        46344.000             low
# 2        71613.000          Medium
# 3              NaN             low
# 4        58293.000          Medium
# ..             ...             ...
# 495      55614.000          Medium
# 496      59432.000          Medium
# 497      55563.000          Medium
# 498      43624.000             low
# 499      41461.000             low
#
# [500 rows x 2 columns]

# %%
df.groupby('income_category').count()['customer_id']
# Out:
# income_category
# High        3
# Medium    204
# low       293
# Name: customer_id, dtype: int64

# %%
df.groupby(['marital_status','educational_level'])['recency'].agg([np.mean,np.median,np.min,np.max])
# Out:
#                                    mean  median  amin  amax
# marital_status educational_level
# Divorced       Basic             62.500  62.500    31    94
#                Graduation        52.028  57.000     3    99
#                High School       87.500  87.500    76    99
#                Master            59.800  62.000     0    92
#                PhD               40.353  35.000     3    88
# Married        Graduation        41.591  32.000     1    97
#                High School       67.000  76.000     0    96
#                Master            45.600  51.000     4    85
#                PhD               65.000  72.500    17    98
# Relationship   Basic             39.333  46.000    13    59
#                Graduation        49.641  51.000     0    96
#                High School       44.909  28.000     2    92
#                Master            32.300  22.500     4    87
#                PhD               41.737  56.000     0    96
# ...

# %%
df.groupby(['marital_status','educational_level']).agg({'recency':'mean','all_purchase':'sum'}).reset_index()
# Out:
#    marital_status educational_level  recency  all_purchase
# 0        Divorced             Basic   62.500             8
# 1        Divorced        Graduation   52.028           367
# 2        Divorced       High School   87.500            10
# 3        Divorced            Master   59.800           111
# 4        Divorced               PhD   40.353           194
# 5         Married        Graduation   41.591           421
# 6         Married       High School   67.000            68
# 7         Married            Master   45.600           142
# 8         Married               PhD   65.000           182
# 9    Relationship             Basic   39.333            15
# 10   Relationship        Graduation   49.641           346
# 11   Relationship       High School   44.909            90
# 12   Relationship            Master   32.300            99
# 13   Relationship               PhD   41.737           250
# 14         Single             Basic   52.000             3
# ...

# %%
pivot=pd.pivot_table(df,values=['all_purchase','recency'],index=['marital_status'],columns=['educational_level'],aggfunc={'recency':np.mean,'all_purchase':np.sum},fill_value=0)

# %%
pivot.head()
# Out:
#                   all_purchase                                    recency  \
# educational_level        Basic Graduation High School Master  PhD   Basic
# marital_status
# Divorced                     8        367          10    111  194  62.500
# Married                      0        421          68    142  182   0.000
# Relationship                15        346          90     99  250  39.333
# Single                       3        523          45    135  119  52.000
# Widow                        0         34           0     14    6   0.000
#
#
# educational_level Graduation High School Master    PhD
# marital_status
# Divorced              52.028      87.500 59.800 40.353
# Married               41.591      67.000 45.600 65.000
# Relationship          49.641      44.909 32.300 41.737
# Single                45.118      51.500 50.583 49.250
# Widow                 61.000       0.000 14.000 25.000

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                    109
# year_of_birth              109
# educational_status_code    137
# marital_status             109
# annual_income              109
# full_name                  109
# educational_level          137
# age                        109
# all_purchase                 0
# income_category              0
# dtype: int64

# %%
df['marital_status']=df['marital_status'].replace('widow','widowed')

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                    109
# year_of_birth              109
# educational_status_code    137
# marital_status             109
# annual_income              109
# full_name                  109
# educational_level          137
# age                        109
# all_purchase                 0
# income_category              0
# dtype: int64

# %%
df[df['cust_id'].isnull()]
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 3       20201704    02-10-2014       26                 2                4
# 7       20201708    05-08-2013       32                 4                4
# 9       20201710     3/13/2014       68                 1                0
# 27      20201728     2/20/2013       19                27                0
# 31      20201732    05-11-2013       56                 2                3
# ..           ...           ...      ...               ...              ...
# 483     20202183     8/19/2012       26                 6                2
# 484     20202184    10/30/2013       30                 4                5
# 485     20202185    10-10-2012       93                 5                4
# 488     20202188     6/26/2013       92                 7               10
# 490     20202190    10/28/2012       96                 4                4
#
#      complaints  calls  intercoms  cust_id  year_of_birth  \
# ...

# %%
df['cust_id']=df['cust_id'].fillna(0)

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                      0
# year_of_birth              109
# educational_status_code    137
# marital_status             109
# annual_income              109
# full_name                  109
# educational_level          137
# age                        109
# all_purchase                 0
# income_category              0
# dtype: int64

# %%
df['year_of_birth']=df['year_of_birth'].fillna(0)

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                      0
# year_of_birth                0
# educational_status_code    137
# marital_status             109
# annual_income              109
# full_name                  109
# educational_level          137
# age                        109
# all_purchase                 0
# income_category              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              500 non-null    int64
#  1   purhcase_date            500 non-null    object
#  2   recency                  500 non-null    int64
#  3   online_purchases         500 non-null    int64
#  4   store_purchases          500 non-null    int64
#  5   complaints               500 non-null    int64
#  6   calls                    500 non-null    int64
#  7   intercoms                500 non-null    int64
#  8   cust_id                  500 non-null    float64
#  9   year_of_birth            500 non-null    Int64
#  10  educational_status_code  363 non-null    object
#  11  marital_status           391 non-null    object
#  12  annual_income            391 non-null    float64
#  13  full_name                391 non-null    object
# ...

# %%
df['educational_status_code']=df['educational_status_code'].fillna("Null")

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                      0
# year_of_birth                0
# educational_status_code      0
# marital_status             109
# annual_income              109
# full_name                  109
# educational_level          137
# age                        109
# all_purchase                 0
# income_category              0
# dtype: int64

# %%
df['marital_status']=df['marital_status'].fillna('Null')

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                      0
# year_of_birth                0
# educational_status_code      0
# marital_status               0
# annual_income              109
# full_name                  109
# educational_level          137
# age                        109
# all_purchase                 0
# income_category              0
# dtype: int64

# %%
df['annual_income']=df['annual_income'].fillna(0)

# %%
df['full_name']=df['full_name'].fillna("Null")

# %%
df['educational_level']=df['educational_level'].fillna('Null')

# %%
df['age']=df['age'].fillna(0)

# %%
df.isnull().sum()
# Out:
# customer_id                0
# purhcase_date              0
# recency                    0
# online_purchases           0
# store_purchases            0
# complaints                 0
# calls                      0
# intercoms                  0
# cust_id                    0
# year_of_birth              0
# educational_status_code    0
# marital_status             0
# annual_income              0
# full_name                  0
# educational_level          0
# age                        0
# all_purchase               0
# income_category            0
# dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('nba - nba.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2   John Holland  Boston Celtics      30       SG   27    6-5     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
gk=df.groupby('Team')

# %%
gk.first()
# Out:
#                                          Name  Number Position  Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore      24       SF   26    6-5
# Boston Celtics                  Avery Bradley       0       PG   25    6-2
# Brooklyn Nets                Bojan Bogdanovic      44       SG   27    6-8
# Charlotte Hornets               Nicolas Batum       5       SG   27    6-8
# Chicago Bulls                Cameron Bairstow      41       PF   25    6-9
# Cleveland Cavaliers       Matthew Dellavedova       8       PG   25    6-4
# Dallas Mavericks              Justin Anderson       1       SG   22    6-6
# Denver Nuggets                 Darrell Arthur       0       PF   28    6-9
# Detroit Pistons                  Joel Anthony      50        C   33    6-9
# Golden State Warriors         Leandro Barbosa      19       SG   33    6-3
# Houston Rockets                  Trevor Ariza       1       SF   30    6-8
# ...

# %%
gk.get_group('Boston Celtics').isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     2
# Salary      1
# dtype: int64

# %%
df.groupby('Team').count()
# Out:
#                         Name  Number  Position  Age  Height  Weight  College  \
# Team
# Atlanta Hawks             15      15        15   15      15      15       11
# Boston Celtics            15      15        15   15      15      15       13
# Brooklyn Nets             15      15        15   15      15      15       13
# Charlotte Hornets         15      15        15   15      15      15       13
# Chicago Bulls             15      15        15   15      15      15       12
# Cleveland Cavaliers       15      15        15   15      15      15       12
# Dallas Mavericks          15      15        15   15      15      15       12
# Denver Nuggets            15      15        15   15      15      15        9
# Detroit Pistons           15      15        15   15      15      15       15
# Golden State Warriors     15      15        15   15      15      15       12
# Houston Rockets           15      15        15   15      15      15       11
# ...

# %%
df.groupby('Team')['Salary'].sum()
# Out:
# Team
# Atlanta Hawks              72902950.0
# Boston Celtics             58541068.0
# Brooklyn Nets              52528475.0
# Charlotte Hornets          78340920.0
# Chicago Bulls              86783378.0
# Cleveland Cavaliers       106988689.0
# Dallas Mavericks           71198732.0
# Denver Nuggets             60121930.0
# Detroit Pistons            67168263.0
# Golden State Warriors      88868997.0
# Houston Rockets            75283021.0
# Indiana Pacers             66751826.0
# Los Angeles Clippers       94854640.0
# Los Angeles Lakers         71770431.0
# Memphis Grizzlies          76550880.0
# Miami Heat                 82515673.0
# Milwaukee Bucks            69603517.0
# Minnesota Timberwolves     59709697.0
# New Orleans Pelicans       82750774.0
# New York Knicks            73303898.0
# Oklahoma City Thunder      93765298.0
# Orlando Magic              60161470.0
# Philadelphia 76ers         30992894.0
# Phoenix Suns               63445135.0
# ...

# %%
f=df.groupby('College')

# %%
f.first()
# Out:
#                                      Name                  Team  Number  \
# College
# Alabama                       Mo Williams   Cleveland Cavaliers      52
# Arizona           Rondae Hollis-Jefferson         Brooklyn Nets      24
# Arizona State                  Jeff Ayres  Los Angeles Clippers      19
# Arkansas                     Bobby Portis         Chicago Bulls       5
# Baylor                         Quincy Acy      Sacramento Kings      13
# ...                                   ...                   ...     ...
# Western Michigan       Shayne Whittington        Indiana Pacers      42
# Wichita State            Cleanthony Early       New York Knicks      11
# Wisconsin                       Jon Leuer          Phoenix Suns      30
# Wyoming                   Larry Nance Jr.    Los Angeles Lakers       7
# Xavier                         David West     San Antonio Spurs      30
#
#                  Position  Age Height  Weight     Salary
# College
# ...

# %%
df['College'].fillna('Unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College      0
# Salary      11
# dtype: int64

# %%
df['Salary']=df['Salary'].fillna(value=df.groupby('Team')['Salary'].mean)

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df.head(10)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2   John Holland  Boston Celtics      30       SG   27    6-5     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# 5   Amir Johnson  Boston Celtics      90       PF   29    6-9     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21    6-8     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22    6-2     190
# 9   Marcus Smart  Boston Celtics      36       PG   22    6-4     220
#
#              College                                             Salary
# 0              Texas                                          7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 32.3+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight
# count  457.000000  457.000000  457.000000
# mean    17.678337   26.938731  221.522976
# std     15.966090    4.404016   26.368343
# min      0.000000   19.000000  161.000000
# 25%      5.000000   24.000000  200.000000
# 50%     13.000000   26.000000  220.000000
# 75%     25.000000   30.000000  240.000000
# max     99.000000   40.000000  307.000000

# %%
df.shape
# Out:
# (457, 9)

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64
